# %%
import numpy as np
import pandas as pd
import seaborn as sns
import string
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/wustl-scada-2018.csv',low_memory=False)
df.head()
# Out:
#    Sport  TotPkts  TotBytes  SrcPkts  DstPkts  SrcBytes  Target
# 0    143        2       180        2        0       180       0
# 1     68        2       684        2        0       684       0
# 2      0        1        60        1        0        60       0
# 3  54949       10       628        4        6       248       0
# 4  54943        8       496        4        4       248       0

# %%
df.shape
# Out:
# (7037983, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7037983 entries, 0 to 7037982
# Data columns (total 7 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Sport     int64
#  1   TotPkts   int64
#  2   TotBytes  int64
#  3   SrcPkts   int64
#  4   DstPkts   int64
#  5   SrcBytes  int64
#  6   Target    int64
# dtypes: int64(7)
# memory usage: 375.9 MB

# %%
df.isnull().sum()
# Out:
# Sport       0
# TotPkts     0
# TotBytes    0
# SrcPkts     0
# DstPkts     0
# SrcBytes    0
# Target      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["Sport"], bins=30, kde=True)
plt.title("Histogram of Sport")
plt.xlabel("Sport")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["TotPkts"], bins=10, kde=True)
plt.title("Histogram of TotPkts")
plt.xlabel("TotPkts")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["TotBytes"], bins=10, kde=True)
plt.title("Histogram of TotBytes")
plt.xlabel("TotBytes")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["SrcPkts"], bins=10, kde=True)
plt.title("Histogram of SrcPkts")
plt.xlabel("SrcPkts")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["DstPkts"], bins=10, kde=True)
plt.title("Histogram of DstPkts")
plt.xlabel("DstPkts")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["SrcBytes"], bins=10, kde=True)
plt.title("Histogram of SrcBytes")
plt.xlabel("SrcBytes")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df["Target"], bins=10, kde=True)
plt.title("Histogram of Target")
plt.xlabel("Target")
plt.ylabel("Frequency")
plt.show()

# %%
corr_matrix = df.corr()

# Generate a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
Y = df[['Target']]
X = df.drop(['Target'], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier


# Train a Random Forest Classifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X, Y)

# Get feature importances
feature_importances = rf_classifier.feature_importances_

# Plot feature importances
plt.figure(figsize=(12, 6))
plt.barh(range(len(feature_importances)), feature_importances, align='center')
plt.yticks(range(len(feature_importances)), X.columns)  # Assuming df is your DataFrame
plt.xlabel('Feature Importance')
plt.title('Feature Importance Plot')
plt.show()
# Out:
# <ipython-input-17-bd3d8449967f>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_classifier.fit(X, Y)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sport', y='Target', data=df)
plt.title('Scatter Plot of sport vs Target')
plt.xlabel('Sport')
plt.ylabel('Target')
plt.show()

# %%
df.columns
# Out:
# Index(['Sport', 'TotPkts', 'TotBytes', 'SrcPkts', 'DstPkts', 'SrcBytes',
#        'Target'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='SrcBytes', y='Target', data=df)
plt.title('Scatter Plot of SrcBytes vs Target')
plt.xlabel('SrcBytes')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='DstPkts', y='Target', data=df)
plt.title('Scatter Plot of DstPkts vs Target')
plt.xlabel('DstPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='SrcPkts', y='Target', data=df)
plt.title('Scatter Plot of SrcPkts vs Target')
plt.xlabel('SrcPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TotBytes', y='Target', data=df)
plt.title('Scatter Plot of TotBytes vs Target')
plt.xlabel('TotBytes')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TotPkts', y='Target', data=df)
plt.title('Scatter Plot of TotPkts vs Target')
plt.xlabel('TotPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Target'], shade=True)
plt.title('KDE Plot of Target')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-11-e32aa500714f>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Target'], shade=True)

# %%
df.columns
# Out:
# Index(['Sport', 'TotPkts', 'TotBytes', 'SrcPkts', 'DstPkts', 'SrcBytes',
#        'Target'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['SrcBytes'], df['Target'], gridsize=20, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of SrcBytes vs Target')
plt.xlabel('SrcBytes')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['DstPkts'], df['Target'], gridsize=30, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of DstPkts vs Target')
plt.xlabel('DstPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['SrcPkts'], df['Target'], gridsize=30, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of SrcPkts vs Target')
plt.xlabel('SrcPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['TotBytes'], df['Target'], gridsize=30, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of TotBytes vs Target')
plt.xlabel('TotBytes')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['TotPkts'], df['Target'], gridsize=30, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of TotPkts vs Target')
plt.xlabel('TotPkts')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['Sport'], df['Target'], gridsize=30, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Hexbin Plot of Sport vs Target')
plt.xlabel('Sport')
plt.ylabel('Target')
plt.show()

# %%
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

# %%
classes = df['Target'].copy()
features = df.drop(['Target'], axis=1)



x_train, x_test, y_train, y_test = train_test_split(features,classes , test_size=0.1, random_state=40)
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
scaler=StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (6334184, 6) (703799, 6) (6334184,) (703799,)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report


y = df['Target'].values
X = df.drop(columns=['Target'])

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define DeepFM model
def DeepFM(input_dim, output_dim):
    # Input layer
    inputs = Input(shape=(input_dim,))

    # FM part
    fm = Dense(1, activation='relu')(inputs)

    # DNN part
    dnn = Dropout(0.5)(inputs)
    dnn = Dense(256, activation='relu')(dnn)
    dnn = Dropout(0.5)(dnn)
    dnn = Dense(128, activation='relu')(dnn)

    # Concatenate FM and DNN parts
    concat = Concatenate()([fm, dnn])

    # Output layer
    output = Dense(output_dim, activation='sigmoid')(concat)

    return Model(inputs=inputs, outputs=output)

# Create and compile the model
model = DeepFM(X_train.shape[1], 1)
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc




# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_classes))

# Generate confusion matrix heatmap
conf_matrix = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=['Normal', 'Intrusion'], yticklabels=['Normal', 'Intrusion'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap WUSTL-IIOT-2018 Multi Class')
plt.show()

# Generate ROC curve and calculate AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve WUSTL-IIOT-2018 Multi Class')
plt.legend(loc="lower right")
plt.show()

# %%
# Train the model
batch_size = 64
epochs = 10
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

# Predict and evaluate further
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/10
# 87975/87975 [==============================] - 389s 4ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 0.0566 - val_accuracy: 0.9926
# Epoch 2/10
# 87975/87975 [==============================] - 387s 4ms/step - loss: 0.0096 - accuracy: 0.9986 - val_loss: 0.0556 - val_accuracy: 0.9929
# Epoch 3/10
# 87975/87975 [==============================] - 423s 5ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.0589 - val_accuracy: 0.9924
# Epoch 4/10
# 87975/87975 [==============================] - 381s 4ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.0463 - val_accuracy: 0.9933
# Epoch 5/10
# 87975/87975 [==============================] - 419s 5ms/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.0453 - val_accuracy: 0.9939
# Epoch 6/10
# 87975/87975 [==============================] - 418s 5ms/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 0.0222 - val_accuracy: 0.9949
# Epoch 7/10
# ...

# %%
epochs = list(range(10))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc




# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_classes))

# Generate confusion matrix heatmap
conf_matrix = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=['Normal', 'Intrusion'], yticklabels=['Normal', 'Intrusion'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap WUSTL-IIOT-2018')
plt.show()

# Generate ROC curve and calculate AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve WUSTL-IIOT-2018')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1326817
#            1       0.98      0.99      0.99     80780
#
#     accuracy                           1.00   1407597
#    macro avg       0.99      1.00      0.99   1407597
# weighted avg       1.00      1.00      1.00   1407597

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc




# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_classes))

# Generate confusion matrix heatmap
conf_matrix = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=['Normal', 'Intrusion'], yticklabels=['Normal', 'Intrusion'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap WUSTL-IIOT-2021')
plt.show()

# Generate ROC curve and calculate AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve WUSTL-IIOT-2021')
plt.legend(loc="lower right")
plt.show()

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_classes))

# Generate confusion matrix heatmap
conf_matrix = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=['Normal', 'Intrusion'], yticklabels=['Normal', 'Intrusion'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap HAI Dataset')
plt.show()

# Generate ROC curve and calculate AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve HAI Dataset')
plt.legend(loc="lower right")
plt.show()

# %%
from keras.utils import plot_model

plot_model(model, to_file='model.png', show_shapes=True)
